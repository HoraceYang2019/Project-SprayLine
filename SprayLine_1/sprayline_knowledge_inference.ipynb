# %% [raw]
# Processing Steps
# Step 1. View thresholds_batch_A.csv
#         ↓ (Run update_knowledge_from_csv.py)
#         Generate **SprayLine_knowledge.ttl   ← contains thresholds**
#
# Step 2. View sprayline_runtime.example.json
#         ↓ (Run sprayline_runtime_inference.py)
#         ↓ (Autoloads both TTLs)
#         SprayLine_ontology.ttl   (structure)
#         + SprayLine_knowledge.ttl (thresholds)
#         + JSON runtime data
#         Generate **SprayLine_runtime_inferred.ttl**

# %% [raw]
# TTL:
#     Input:
#         1. SprayLine_ontology.ttl
#     Output:
#         2. SprayLine_knowledge.ttl
#         3. SprayLine_runtime_inferred.ttl
#
# Data:
#     Input:
#         1. thresholds_batch_A.csv
#         2. sprayline_runtime.example.json
#     Output:
#         3. test_run_output.txt
#
# Schema:
#     Input:
#         1. sprayline_runtime.schema.json
#
# Python:
#     1. update_knowledge_from_csv.py
#     2. sprayline_runtime_inference.py
#
# README.md

# %% [markdown]
# ----
#
# #### Step 1: SprayLine_knowledge.ttl from thresholds_batch_A.csv

# %% [markdown]
# @prefix mis: <http://nkust.edu.tw/mislab#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# mis:FilterEarly mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxFlowLossRatio 0.15 ;
#     mis:minFlowLossRatio 0.0 ;
#     mis:severityRank 0 .
#
# mis:FilterModerateBlock mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxFlowLossRatio 0.387 ;
#     mis:minFlowLossRatio 0.132 ;
#     mis:severityRank 1 .
#
# mis:FilterSevereBlock mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxFlowLossRatio 1.0 ;
#     mis:minFlowLossRatio 0.4 ;
#     mis:severityRank 2 .
#
# mis:IssuedProcess mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxSeverityRank 1 ;
#     mis:maxThicknessErrorRatio 0.12 ;
#     mis:minSeverityRank 1 ;
#     mis:minThicknessErrorRatio 0.06 .
#
# mis:NozzleBlock mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxPressureErrorRatio 1.0 ;
#     mis:maxSprayWidthErrorRatio 1.0 ;
#     mis:minPressureErrorRatio 0.25 ;
#     mis:minSprayWidthErrorRatio 0.25 ;
#     mis:severityRank 2 .
#
# mis:NozzleEarly mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxPressureErrorRatio 0.1 ;
#     mis:maxSprayWidthErrorRatio 0.1 ;
#     mis:minPressureErrorRatio 0.0 ;
#     mis:minSprayWidthErrorRatio 0.0 ;
#     mis:severityRank 0 .
#
# mis:NozzleWear mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxPressureErrorRatio 0.25 ;
#     mis:maxSprayWidthErrorRatio 0.25 ;
#     mis:minPressureErrorRatio 0.1 ;
#     mis:minSprayWidthErrorRatio 0.1 ;
#     mis:severityRank 1 .
#
# mis:StableProcess mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxSeverityRank 0 ;
#     mis:maxThicknessErrorRatio 0.06 ;
#     mis:minSeverityRank 0 ;
#     mis:minThicknessErrorRatio 0.0 .
#
# mis:UnstableProcess mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" ;
#     mis:maxSeverityRank 9 ;
#     mis:maxThicknessErrorRatio 1.0 ;
#     mis:minSeverityRank 2 ;
#     mis:minThicknessErrorRatio 0.12 .
#
# <http://nkust.edu.tw/mislab/cnc/knowledge/sprayline/batch-A> a owl:Ontology ;
#     rdfs:label "SprayLine learned threshold knowledge - batch A"@en ;
#     mis:confidence 0.94 ;
#     mis:derivedFromDataset "sprayline_2026_batch_A" .

# %% [markdown]
# ---
# #### Step 2. sprayline_runtime.example.json

# %% [markdown]
# {
#   "window_id": "w0413004",
#   "machine_id": "spray_machine_A",
#   "timestamp": "2026-04-26T09:00:00+08:00",
#   "filter": {
#     "in_flow": 100.0,
#     "out_flow": 72.0
#   },
#   "nozzle": {
#     "spray_width": 82.0,
#     "spray_pressure": 2.4
#   },
#   "quality": {
#     "measured_thickness": 51.5
#   },
#   "target": {
#     "spray_width": 80.0,
#     "spray_pressure": 2.5,
#     "thickness": 50.0
#   }
# }

# %% [markdown]
# #### sprayline_runtime_inference.py

# %% [markdown]
# Load SprayLine_ontology.ttl   (structure) and SprayLine_knowledge.ttl (thresholds)

# %% [markdown]
# #### SprayLine_runtime_inferred.ttl

# %% [raw]
# test_run_output.txt
# {
#   "window_id": "w0413004",
#   "filter_state": "FilterModerateBlock",
#   "nozzle_state": "NozzleEarly",
#   "process_state": "StableProcess",
#   "flow_loss_ratio": 0.28,
#   "spray_width_error_ratio": 0.025,
#   "pressure_error_ratio": 0.04,
#   "thickness_error_ratio": 0.03,
#   "confidence": 0.72,
#   "diagnosis_uri": "http://nkust.edu.tw/mislab/cnc/ontology/sth#Diagnosis_w0413004_StableProcess"
# }
